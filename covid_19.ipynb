# %% [markdown]
# <a href="https://colab.research.google.com/github/kc2409/cl1/blob/main/covid_19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
covid_19=pd.read_csv('/covid_19_data.csv')

# %%
covid_19.shape
# Out:
# (321, 6)

# %%
covid_19.count()
# Out:
# Date         321
# State        140
# Region       321
# Confirmed    321
# Deaths       321
# Recovered    321
# dtype: int64

# %%
covid_19.describe
# Out:
# <bound method NDFrame.describe of           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [321 rows x 6 columns]>

# %%
covid_19.isnull().sum()
# Out:
# Date           0
# State        181
# Region         0
# Confirmed      0
# Deaths         0
# Recovered      0
# dtype: int64

# %%
sns.heatmap(covid_19.isnull())
plt.show()

# %%
x=covid_19['Deaths']
y=covid_19['Confirmed']
print("No of total death cases:",x.sum())

print("Number of total confirmed cases:",y.sum())
# Out:
# No of total death cases: 227638
# Number of total confirmed cases: 3193886

# %%
x=covid_19.groupby('Region')['Deaths'].sum()
y=covid_19['Region']
plt.rcParams["figure.figsize"] = [12.50, 3.50]
plt.rcParams["figure.autolayout"] = True
#plt.xticks(fontsize=10)
plt.tick_params(axis='x', which='major', labelsize=5)
plt.xticks(x, [str(i) for i in x], rotation=90)
#np.linspace(0,178,20)
plt.plot(x)
fig=plt.figure()
spacing=0.4
fig.subplots_adjust(bottom=spacing)
y
# Out:
# 0         Afghanistan
# 1             Albania
# 2             Algeria
# 3             Andorra
# 4              Angola
#             ...
# 316                US
# 317    Mainland China
# 318            Canada
# 319    Mainland China
# 320    Mainland China
# Name: Region, Length: 321, dtype: object
